# %%
import requests
from pprint import pprint

# %%
URL = "http://maps.googleapis.com/maps/api/geocode/json"
location = "delhi technological university"
PARAMS = {'address':location}
r = requests.get(url = URL, params = PARAMS)
data = r.json()

# %%
data
# Out:
# {'error_message': 'You must use an API key to authenticate each request to Google Maps Platform APIs. For additional information, please refer to http://g.co/dev/maps-no-account',
#  'results': [],
#  'status': 'REQUEST_DENIED'}

# %%
req = requests.get('https://www.google.com/Ionatan')

req.status_code
# Out:
# 404

# %%
req = requests.get('https://en.wikipedia.org/wiki/Newton')

pprint(req.url)
# Out:
# 'https://en.wikipedia.org/wiki/Newton'

# %%
URL = "http://google.com/search"
search = "Ciencia de datos"
PARAMS = {'q':search}

req = requests.get(url=URL, params=PARAMS)

pprint (req.url)
# Out:
# 'http://www.google.com/search?q=Ciencia+de+datos'
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# File c:\Users\Ionatan\anaconda3\envs\DH\lib\site-packages\requests\models.py:910, in Response.json(self, **kwargs)
#     <a href='file:///c%3A/Users/Ionatan/anaconda3/envs/DH/lib/site-packages/requests/models.py?line=908'>909</a> try:
# --> <a href='file:///c%3A/Users/Ionatan/anaconda3/envs/DH/lib/site-packages/requests/models.py?line=909'>910</a>     return complexjson.loads(self.text, **kwargs)
#     <a href='file:///c%3A/Users/Ionatan/anaconda3/envs/DH/lib/site-packages/requests/models.py?line=910'>911</a> except JSONDecodeError as e:
#     <a href='file:///c%3A/Users/Ionatan/anaconda3/envs/DH/lib/site-packages/requests/models.py?line=911'>912</a>     # Catch JSON-related errors and raise as requests.JSONDecodeError
# ...

# %%
from PIL import Image
from io import BytesIO

URL = "https://baobab-poseannotation-appfile.s3.amazonaws.com/media/project_5/images/images01/01418849d54b3005.o.1.jpg"


response = requests.get(URL)
img = Image.open(BytesIO(response.content))
pprint(response.headers)
img.show()
# Out:
# {'x-amz-id-2': 'RrgXGz8FJpJBpeyFGvzZXCQAcz84vHJ2R2T6v78nA+Rr9AwsvD0rysrFlZW8Ag9qOaNdq80ma+g=', 'x-amz-request-id': 'QG3PVA3PS2KJ4QMZ', 'Date': 'Thu, 09 Jun 2022 18:18:44 GMT', 'Last-Modified': 'Tue, 13 Feb 2018 08:36:49 GMT', 'ETag': '"d1a74d601959ae4210c1ba3c3acac270"', 'Accept-Ranges': 'bytes', 'Content-Type': 'image/jpeg', 'Server': 'AmazonS3', 'Content-Length': '3771541'}
